# %% [markdown]
# <div style="background-color:#086fcb;color:white;width:100%;height:65px;text-align:center;font-size:20px;font-family:Georgia;font-weight:bolder;border-radius:12px;">
#    <h1 style="padding:12px;">CR7 - EDA & Analytics</h1>
# </div>

# %% [markdown]
# <img src="cr7.jpg" alt="ronaldo" width="100%" height="450px">

# %% [markdown]
# <div style="background-color:#086fcb;color:white;width:100%;height:65px;text-align:center;font-size:20px;font-family:Georgia;font-weight:bolder;border-radius:12px;">
#    <h1 style="padding:12px;">Introduction</h1>
# </div>

# %% [markdown]
# # Introduction
#
# Cristiano Ronaldo dos Santos Aveiro, born on February 5, 1985, in Funchal, Madeira, Portugal, is widely regarded as one of the greatest football players of all time. He began his professional career with Sporting CP before moving to Manchester United in 2003, where he gained international fame. Ronaldo has since played for Real Madrid and Juventus, and he returned to Manchester United in 2021. Known for his exceptional goal-scoring ability, athleticism, and work ethic, he has won multiple Ballon d'Or awards and numerous titles, including UEFA Champions League trophies.
#
# __Ronaldo__ was born into a working-class family; his father, José Denis Aveiro, was a municipal gardener, and his mother, Maria Dolores dos Santos Aveiro, worked as a cook. He has one older brother, Hugo, and two older sisters, Elma and Liliana. His family has been very supportive of his football career, and he often credits them for his success.
#
# As of 2023, Cristiano Ronaldo's salary is estimated to be around £173 million per year, which includes his earnings from club contracts and endorsements. This figure reflects a significant contribution to the Portuguese economy, as he is one of the highest-paid athletes in the world.
#
# Ronaldo is also a devoted father to five children: Cristiano Ronaldo Jr. (born June 17, 2010), twins Eva Maria and Mateo (born June 8, 2017), Alana Martina (born November 12, 2017), and Bella Esmeralda (born April 18, 2022). He often shares moments with his children on social media, showcasing his commitment to family life.

# %% [markdown]
# # Data Load

# %%
# libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


import warnings

# %%
df=pd.read_csv("/kaggle/input/cr7-cristiano-ronaldo-all-club-goals-stats/data.csv")

# %%
df.sample(10)
# Out:
#      Season          Competition Matchday      Date Venue         Club  \
# 591   18/19              Serie A       22  02-02-19     H  Juventus FC
# 258   11/12               LaLiga       33  04-11-12     A  Real Madrid
# 236   11/12               LaLiga        1   1/22/12     H  Real Madrid
# 502   16/17  FIFA Club World Cup    Final  12/18/16     H  Real Madrid
# 643   20/21              Serie A        7  11-08-20     A  Juventus FC
# 361   13/14               LaLiga       27  03-09-14     H  Real Madrid
# 431   14/15               LaLiga       37   5/17/15     A  Real Madrid
# 419   14/15               LaLiga       29  04-05-15     H  Real Madrid
# 317  Dec-13               LaLiga       31   4/14/13     A  Real Madrid
# 321  Dec-13               LaLiga       34  05-04-13     H  Real Madrid
#
#                    Opponent   Result Playing_Position Minute At_score  \
# 591       Parma Calcio 1913     3:03               LW     66     3:01
# ...

# %% [markdown]
# # Exploration Data Analysis

# %%
df.shape
# Out:
# (710, 13)

# %%
df.columns
# Out:
# Index(['Season', 'Competition', 'Matchday', 'Date', 'Venue', 'Club',
#        'Opponent', 'Result', 'Playing_Position', 'Minute', 'At_score', 'Type',
#        'Goal_assist'],
#       dtype='object')

# %%
df.head(10)
# Out:
#   Season               Competition      Matchday      Date Venue  \
# 0  02/03             Liga Portugal             6  10-07-02     H
# 1  02/03             Liga Portugal             6  10-07-02     H
# 2  02/03             Liga Portugal             8  10/26/02     A
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02     H
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02     H
# 5  03/04            Premier League            11  11-01-03     H
# 6  03/04                    FA Cup   Fifth Round   2/14/04     H
# 7  03/04            Premier League            29   3/20/04     H
# 8  03/04            Premier League            32  04-10-04     A
# 9  03/04            Premier League            38   5/15/04     A
#
#                 Club                 Opponent Result Playing_Position Minute  \
# 0        Sporting CP            Moreirense FC   3:00               LW     34
# 1        Sporting CP            Moreirense FC   3:00               LW   90+5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 710 entries, 0 to 709
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Season            710 non-null    object
#  1   Competition       710 non-null    object
#  2   Matchday          710 non-null    object
#  3   Date              710 non-null    object
#  4   Venue             710 non-null    object
#  5   Club              710 non-null    object
#  6   Opponent          710 non-null    object
#  7   Result            710 non-null    object
#  8   Playing_Position  652 non-null    object
#  9   Minute            710 non-null    object
#  10  At_score          710 non-null    object
#  11  Type              695 non-null    object
#  12  Goal_assist       464 non-null    object
# dtypes: object(13)
# memory usage: 72.2+ KB

# %%
# unique values counts
pd.DataFrame(df.apply(lambda column: len(column.unique())),columns=['Unique Values Count'])
# Out:
#                   Unique Values Count
# Season                             21
# Competition                        17
# Matchday                           52
# Date                              468
# Venue                               2
# Club                                5
# Opponent                          129
# Result                             57
# Playing_Position                    6
# Minute                            106
# At_score                           43
# Type                               12
# Goal_assist                        92

# %%
df.describe().T
# Out:
#                  count unique                top freq
# Season             710     21              14/15   61
# Competition        710     17             LaLiga  311
# Matchday           710     52        Group Stage   75
# Date               710    468           09-12-15    5
# Venue              710      2                  H  404
# Club               710      5        Real Madrid  450
# Opponent           710    129         Sevilla FC   27
# Result             710     57               3:00   49
# Playing_Position   652      5                 LW  356
# Minute             710    106                 90   17
# At_score           710     43               1:00  111
# Type               695     11  Right-footed shot  253
# Goal_assist        464     91      Karim Benzema   44

# %%
pd.DataFrame(df.apply(lambda column: column.isnull().sum()), columns=['Null Values Count'])
# df.isnull().sum()
# Out:
#                   Null Values Count
# Season                            0
# Competition                       0
# Matchday                          0
# Date                              0
# Venue                             0
# Club                              0
# Opponent                          0
# Result                            0
# Playing_Position                 58
# Minute                            0
# At_score                          0
# Type                             15
# Goal_assist                     246

# %% [markdown]
# # Visualization

# %%
# null values in heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cmap='viridis', cbar=False, yticklabels=False)
plt.title('Null Values Heatmap')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Playing_Position', order=df['Playing_Position'].value_counts().index)
plt.title('Distribution of Playing Positions')
plt.xticks(rotation=45)
plt.ylabel('Count')
plt.show()

# %%
# Goals per Club
goals_per_club = df['Club'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=goals_per_club.index, y=goals_per_club.values)
plt.title('Total Goals by Club')
plt.xticks(rotation=45)
plt.ylabel('Goals Count')
plt.show()

# %%
# matches over sessions
matches_per_season = df['Season'].value_counts().sort_index()
plt.figure(figsize=(20, 6))
sns.lineplot(x=matches_per_season.index, y=matches_per_season.values, marker='o')
plt.title('Number of Matches per Season')
plt.xticks(rotation=45)
plt.ylabel('Number of Matches')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
pd.DataFrame(df.Type.value_counts())
# Out:
#                         count
# Type
# Right-footed shot         253
# Penalty                   132
# Left-footed shot          113
# Header                    112
# Direct free kick           49
# Tap-in                     14
# Long distance kick          9
# Counter attack goal         6
# Penalty rebound             3
# Solo run                    2
# Deflected shot on goal      2

# %%
plt.figure(figsize=(8, 8))
df['Type'].value_counts().plot.pie(autopct='%10.1f%%', startangle=180)
plt.title('Goals by Type')
plt.ylabel('')
plt.show()

# %%
# Count the occurrences of each type
goals_by_type = df['Type'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=goals_by_type.index, y=goals_by_type.values)
plt.title('Goals by Type')
plt.xlabel('Type')
plt.ylabel('Count of Goals')
plt.xticks(rotation=45)
plt.show()

# %%
# Count the number of goals per competition
goals_per_competition = df['Competition'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=goals_per_competition.index, y=goals_per_competition.values, palette='viridis')

# Add labels and title
plt.title('Goals per Competition')
plt.xlabel('Competition')
plt.ylabel('Count of Goals')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
pd.DataFrame(df.Competition.value_counts())
# Out:
#                                   count
# Competition
# LaLiga                              311
# UEFA Champions League               140
# Premier League                      103
# Serie A                              81
# Copa del Rey                         22
# FA Cup                               13
# Saudi Pro League                      9
# FIFA Club World Cup                   7
# Italy Cup                             4
# EFL Cup                               4
# Supercopa                             4
# Liga Portugal                         3
# Taca de Portugal Placard              2
# Supercoppa Italiana                   2
# UEFA Super Cup                        2
# Europa League                         2
# UEFA Champions League Qualifying      1

# %%
# Count the number of goals per competition
goals_per_competition = df['Season'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=goals_per_competition.index, y=goals_per_competition.values, palette='viridis')

# Add labels and title
plt.title('Goals per Season')
plt.xlabel('Season')
plt.ylabel('Count of Goals')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
pd.DataFrame(df.Season.value_counts()).T
# Out:
# Season  14/15  11/12  Dec-13  10/11  13/14  15/16  17/18  16/17  07/08  19/20  \
# count      61     60      55     53     51     51     44     42     42     37
#
# Season  ...  09/10  18/19  08/09  21/22  06/07  05/06  22/23  04/05  03/04  \
# count   ...     33     28     26     24     23     12     12      9      6
#
# Season  02/03
# count       5
#
# [1 rows x 21 columns]

# %%
# Count the number of goals per competition
goals_per_competition = df['Club'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=goals_per_competition.index, y=goals_per_competition.values, palette='viridis')

# Add labels and title
plt.title('Goals per Club')
plt.xlabel('Club')
plt.ylabel('Count of Goals')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 8))
df['Club'].value_counts().plot.pie(autopct='%10.1f%%', startangle=180)
plt.title('Goals by Club')
plt.ylabel('')
plt.show()

# %%
pd.DataFrame(df.Club.value_counts())
# Out:
#                    count
# Club
# Real Madrid          450
# Manchester United    145
# Juventus FC          101
# Al-Nassr FC            9
# Sporting CP            5

# %%
# Count the number of goals per competition
goals_per_competition = df['Playing_Position'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=goals_per_competition.index, y=goals_per_competition.values, palette='viridis')

# Add labels and title
plt.title('Goals per Competition')
plt.xlabel('Positions')
plt.ylabel('Count of Goals')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
plt.figure(figsize=(8, 8))
df['Playing_Position'].value_counts().plot.pie(autopct='%10.1f%%', startangle=180)
plt.title('Goals by Type')
plt.ylabel('')
plt.show()

# %%
# Count the number of goals per competition
goals_per_competition = df['At_score'].value_counts()

# Create a bar plot
plt.figure(figsize=(20, 6))
sns.barplot(x=goals_per_competition.index, y=goals_per_competition.values, palette='viridis')

# Add labels and title
plt.title('Goals per At Score')
plt.xlabel('At score')
plt.ylabel('Count of Goals')
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %% [markdown]
# # goals per opponents

# %%
# Count occurrences of each opponent
opponent_counts = df['Opponent'].value_counts()
opponents = opponent_counts.index
counts = opponent_counts.values

# Create a color mapping for competitions
colors = {comp: idx for idx, comp in enumerate(df['Competition'].unique())}
df['Color'] = df['Competition'].map(colors)

# Set up the figure
plt.figure(figsize=(30, 5))

# Create a bar plot
bars = plt.bar(opponents, counts, color=[plt.cm.tab10(df['Color'][i]) for i in range(len(df))])

# Rotate x-ticks
plt.xticks(rotation='vertical')

# Set title
plt.title("Goals per Opponent", fontsize=30)

# Show the plot
plt.show()

# %%
# Count occurrences of each opponent
opponent_counts = df['Opponent'].value_counts()
opponents = opponent_counts.index

# Set up the figure
plt.figure(figsize=(20, 5))

# Create a bar plot
plt.bar(opponents, opponent_counts, color='blue')

# Rotate x-ticks and set fontsize
plt.xticks(fontsize=9, rotation='vertical')

# Set title
plt.title("Goals per Opponents", fontsize=30)

# Show the plot
plt.show()

# %%
# Count the occurrences of each type in 'Goal_assist'
goal_assist_counts = df['Goal_assist'].value_counts()

# Set the figure size
plt.figure(figsize=(30, 5))

# Create the bar plot
plt.bar(goal_assist_counts.index, goal_assist_counts.values, color='skyblue')

# Set the title and labels
plt.title("Goals Assist", fontsize=30)
plt.xlabel('Goal Assist Types', fontsize=20)
plt.ylabel('Count', fontsize=20)

# Rotate x-axis labels for better visibility
plt.xticks(rotation='vertical')

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Set the figure size
plt.figure(figsize=(10, 8))

# Set the title
plt.title('Goals per Venue', fontsize=10)

# Define custom colors
colors = ['#ff9999', '#66b3ff']  # You can choose any colors you like

# Create the pie chart
df.Venue.value_counts().plot(
    kind='pie',
    labels=['Home', 'Away'],
    wedgeprops=dict(width=.7),
    autopct='%1.0f%%',
    startangle=-20,
    textprops={'fontsize': 10},
    colors=colors  # Apply the custom colors
)

# Show the plot
plt.show()
